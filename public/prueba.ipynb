# %%
import requests

url = "https://opendata.vlci.valencia.es/api/3/action/datastore_search?resource_id=19b5a1a7-5888-4d3e-b69b-3c1436d64e6e&limit=20"

response = requests.get(url)

try:
    data = response.json()
    print("OK, datos recibidos")
    print(data["result"])
except Exception as e:
    print("Error al parsear JSON:", e)
    print("Respuesta real:\n", response.text[:300])
# Out:
# OK, datos recibidos
# ...
